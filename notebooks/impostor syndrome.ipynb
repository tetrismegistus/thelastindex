# %% [markdown]
# # TextureAndColors
#
# who are you?

# %% [markdown]
# ![image.png](attachment:719c74a8-bc94-4070-9146-43224e16690a.png)

# %% [markdown]
# ![image.png](attachment:7d8b62ea-e818-4bbf-aea6-8f6f00c8561d.png)
# ![image.png](attachment:dfdc1ce2-7a5e-4501-ba05-28892c3cd319.png)
