# %% [markdown]
# # let's have some fun
# ## We've got a name
# We have text and text and text. we're generating text by hand?
#
# Why?
#
# It's 2025 because apparently it's bad.

# %% [markdown]
# https://pelicanthemes.com/cid/
#
# ![image.png](attachment:d51e4bf0-4f41-4a98-8d1e-30474701db7e.png)

# %% [markdown]
# ![image.png](attachment:33f1fe81-1a4a-4747-8426-fb204eefa3f6.png)
#
# https://fonts.google.com/specimen/Lancelot?categoryFilters=Serif:%2FSerif%2FOld+Style+Garalde;Feeling:%2FExpressive%2FBusiness
